# %% [raw]
#  1. In the below elements which of them are values or an expression? eg:-  values can be integer or string and expressions will be mathematical operators.
#
# *
# 'hello'
# -87.8
# -
#
# /
# 	+
# 6
#
#
# Ans : -
#
# Integer -   -87.8 , 6
# String -'hello'
#
# Expression Mathematical operator -   *,-,/,+

# %% [raw]
# 2. What is the difference between string and variable?
#
# Ans -
# Variable is a container which holds the value.
# String - String is the cluster of characters

# %%
3. Describe three different data types.

Ans - 

Int datatype - It defines the variable to store the integer like - 1,2,3
Float datatype - It defines the variable to store the decimal type of value like - 1.2,2.4
String datatype - it defines the variable to store the cluster of characters

# %%
4. What is an expression made up of? What do all expressions do?

Ans - 
Expression consists of numbers and mathematical operators which gives the sensible output.

# %%
5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?

Ans :- 
    
Statement - We are declaring about something and it gives the fixed value after running it. 
Expression - In expression, we define how the system should execute and give the sensible output.

# %%
6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

Ans - 23

# %%
7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3

Ans - 1. spamspamspam
      2. spamspamspam

# %%
8. Why is eggs a valid variable name while 100 is invalid?

Ans - 100 is number , so when we assign any value for 100 it throws error.

# %%
# Ref - https://www.hackerearth.com/practice/notes/strings-and-string-manupulation-1/
9. What three functions can be used to get the integer, floating-point number, or string version of a value?

Ans - Integer - int(),float(),str()
      floating-point number  - int(),float(),str()
      String - strlen(),strcpy(),strcmp()

# %%
10. Why does this expression cause an error? How can you fix it?
'I have eaten ' + 99 + ' burritos.'

Ans -  str and integer are getting added because of which it is throwing the error
  We can fix it by converting the 99 to string
 'I have eaten ' + '99' + ' burritos.'
